# %%
1. Missing closing bracket
   print("Hello World"

# %%
2. Invalid variable assignment
   10 = 20

# %%
3. Missing colon
   if 10 > 5
   print("10 is greater")

# %%
4. Missing quotation mark
   name = "Rahul

# %%
5. Incorrect indentation
   if True:
   print("Hello")

# %%
6. Missing closing parenthesis
   result = (10 + 20

# %%
7. Invalid syntax in list
   numbers = [1, 2, 3, 4

# %%
8. Missing colon in function definition
   def greet()
   print("Hello")

# %%
9. Missing colon in for loop
   for i in range(5)
   print(i)

# %%
10.Incorrect use of if-else
   if 5 > 2:
    print("Yes")
   else
    print("No")
